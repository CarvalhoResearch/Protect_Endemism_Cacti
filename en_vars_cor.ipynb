# %%
import pandas as pd
from glob import glob
import geopandas as gpd
import os
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# %load_ext rpy2.ipython
# Out:
# /home/eduardo/.local/lib/python3.6/site-packages/pandas/compat/_optional.py:106: UserWarning: Pandas requires version '1.2.1' or newer of 'bottleneck' (version '1.2.0' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
# %%R
# library(dismo)
# library(sf)
# library(flora)
# library(virtualspecies)
# library(raster)
# library(RColorBrewer)
# Out:
# R[write to console]: Carregando pacotes exigidos: raster
#
# R[write to console]: Carregando pacotes exigidos: sp
#
# R[write to console]: Linking to GEOS 3.8.0, GDAL 2.4.2, PROJ 5.2.0
#
# R[write to console]: WARNING: different compile-time and runtime versions for GEOS found:
#
# R[write to console]: Linked against: 3.8.0-CAPI-1.13.1  compiled against: 3.7.1-CAPI-1.11.1
#
# R[write to console]: It is probably a good idea to reinstall sf, and maybe rgeos and rgdal too
#
# R[write to console]:
# Attaching package: ‘flora’
#
#
# R[write to console]: The following object is masked from ‘package:raster’:
#
#     trim

# %%
# %%R
# files<-list.files('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/enviromental_data/soil/world/1km/',pattern='.tif')
# path<-paste('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/enviromental_data/soil/world/1km/',files,sep='')

# %%
# %%R
# caatinga <- read_sf('/home/eduardo/projetos/endemic_vs_desmat/data/caatinga/caatinga_olson.shp')
#
#
#   for (i in 1:length(path)){
#   fname<-paste('/home/eduardo/projetos/endemic_vs_desmat/data/env/',files[i],sep='')
#   raster_data<-raster(path[i])
#   croped<-crop(raster_data,extent(caatinga))
#   masked<-mask(croped,caatinga)
#   writeRaster(masked, filename=fname, format="GTiff", overwrite=TRUE)
#   }
# Out:
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# ...

# %%
# %%R
# files<-list.files('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/enviromental_data/climate/current/world/chelsea/',pattern='.tif')
# path<-paste('/home/eduardo/projetos/conservacao_de_plantas_mudancas_climaticas/data/enviromental_data/climate/current/world/chelsea/',files,sep='')
#
# print(files)
# Out:
#  [1] "CHELSA_bio10_1.tif"
#  [2] "CHELSA_bio10_10.tif"
#  [3] "CHELSA_bio10_11.tif"
#  [4] "CHELSA_bio10_12.tif"
#  [5] "CHELSA_bio10_13.tif"
#  [6] "CHELSA_bio10_14.tif"
#  [7] "CHELSA_bio10_15.tif"
#  [8] "CHELSA_bio10_16.tif"
#  [9] "CHELSA_bio10_17.tif"
# [10] "CHELSA_bio10_18.tif"
# [11] "CHELSA_bio10_19.tif"
# [12] "CHELSA_bio10_2.tif"
# [13] "CHELSA_bio10_3.tif"
# [14] "CHELSA_bio10_4.tif"
# [15] "CHELSA_bio10_5.tif"
# [16] "CHELSA_bio10_6.tif"
# [17] "CHELSA_bio10_7.tif"
# [18] "CHELSA_bio10_8.tif"
# [19] "CHELSA_bio10_9.tif"
# [20] "CHELSA_prec_1_V1.2_land.tif"
# [21] "CHELSA_prec_10_V1.2_land.tif"
# [22] "CHELSA_prec_11_V1.2_land.tif"
# [23] "CHELSA_prec_12_V1.2_land.tif"
# [24] "CHELSA_prec_2_V1.2_land.tif"
# [25] "CHELSA_prec_3_V1.2_land.tif"
# [26] "CHELSA_prec_4_V1.2_land.tif"
# [27] "CHELSA_prec_5_V1.2_land.tif"
# [28] "CHELSA_prec_6_V1.2_land.tif"
# [29] "CHELSA_prec_7_V1.2_land.tif"
# [30] "CHELSA_prec_8_V1.2_land.tif"
# [31] "CHELSA_prec_9_V1.2_land.tif"
# ...

# %%
# %%R
# caatinga <- read_sf('/home/eduardo/projetos/endemic_vs_desmat/data/caatinga/caatinga_olson.shp')
#
# #para cada raster de solo recorta e cria um novo com a extenção da camada caatinga
#   for (i in 1:length(path)){
#   fname<-paste('/home/eduardo/projetos/endemic_vs_desmat/data/env/',files[i],sep='')
#   raster_data<-raster(path[i])
#   croped<-crop(raster_data,extent(caatinga))
#   masked<-mask(croped,caatinga)
#   writeRaster(masked, filename=fname, format="GTiff", overwrite=TRUE)
#   }
# Out:
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# ...

# %%
# %%R
#
# files<-list.files('/home/eduardo/projetos/endemic_vs_desmat/data/env/selected/')
# setwd('/home/eduardo/projetos/endemic_vs_desmat/data/env/selected/')
# env<-stack(files)
# Out:
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# ...

# %%
# %%R -w 900 -h 900
#
# plot(env,col='BrBg')
# Out:
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: NOTE: rgdal::checkCRSArgs: no proj_defs.dat in PROJ.4 shared files
#
# R[write to console]: Error in graphics::rasterImage(x, e[1], e[3], e[2], e[4], interpolate = interpolate) :
#   invalid color name 'BrBg'
# Calls: <Anonymous> ... .local -> .plotraster2 -> .rasterImagePlot -> <Anonymous>
# Error in graphics::rasterImage(x, e[1], e[3], e[2], e[4], interpolate = interpolate) :
#   invalid color name 'BrBg'
# Calls: <Anonymous> ... .local -> .plotraster2 -> .rasterImagePlot -> <Anonymous>

# %%
# %%R
# removeCollinearity(env,plot=TRUE)
# Out:
# [[1]]
# [1] "CLYPPT_M_sl1_1km_ll" "CLYPPT_M_sl2_1km_ll" "CLYPPT_M_sl3_1km_ll"
# [4] "CLYPPT_M_sl4_1km_ll" "CLYPPT_M_sl5_1km_ll" "CLYPPT_M_sl6_1km_ll"
# [7] "CLYPPT_M_sl7_1km_ll"
#
# [[2]]
# [1] "SLTPPT_M_sl1_1km_ll" "SLTPPT_M_sl2_1km_ll" "SLTPPT_M_sl3_1km_ll"
# [4] "SLTPPT_M_sl4_1km_ll" "SLTPPT_M_sl5_1km_ll" "SLTPPT_M_sl6_1km_ll"
# [7] "SLTPPT_M_sl7_1km_ll"
#
# [[3]]
# [1] "SNDPPT_M_sl1_1km_ll" "SNDPPT_M_sl2_1km_ll" "SNDPPT_M_sl3_1km_ll"
# [4] "SNDPPT_M_sl4_1km_ll" "SNDPPT_M_sl5_1km_ll" "SNDPPT_M_sl6_1km_ll"
# [7] "SNDPPT_M_sl7_1km_ll"

# %%
# %%R
# removeCollinearity(env,plot=TRUE)
# Out:
# [[1]]
# [1] "ACDWRB_M_ss_1km_ll"
#
# [[2]]
# [1] "AWCh1_M_sl1_1km_ll" "AWCh2_M_sl1_1km_ll" "AWCh3_M_sl1_1km_ll"
#
# [[3]]
# [1] "AWCh1_M_sl2_1km_ll" "AWCh1_M_sl3_1km_ll" "AWCh2_M_sl2_1km_ll"
# [4] "AWCh2_M_sl3_1km_ll" "AWCh3_M_sl2_1km_ll" "AWCh3_M_sl3_1km_ll"
#
# [[4]]
# [1] "AWCh1_M_sl4_1km_ll" "AWCh2_M_sl4_1km_ll" "AWCh3_M_sl4_1km_ll"
#
# [[5]]
# [1] "AWCh1_M_sl5_1km_ll" "AWCh2_M_sl5_1km_ll"
#
# [[6]]
# [1] "AWCh1_M_sl6_1km_ll" "AWCh1_M_sl7_1km_ll" "AWCh2_M_sl6_1km_ll"
# [4] "AWCh2_M_sl7_1km_ll"
#
# [[7]]
# [1] "AWCh3_M_sl5_1km_ll"
#
# [[8]]
# [1] "AWCh3_M_sl6_1km_ll" "AWCh3_M_sl7_1km_ll"
#
# [[9]]
# [1] "AWCtS_M_sl1_1km_ll" "AWCtS_M_sl2_1km_ll" "AWCtS_M_sl3_1km_ll"
# [4] "AWCtS_M_sl4_1km_ll" "AWCtS_M_sl5_1km_ll" "AWCtS_M_sl6_1km_ll"
# [7] "AWCtS_M_sl7_1km_ll"

# %%
# %%R
# removeCollinearity(env,plot=TRUE)
# Out:
# [[1]]
# [1] "CHELSA_bio10_1"  "CHELSA_bio10_11" "CHELSA_bio10_18" "CHELSA_bio10_6"
# [5] "CHELSA_bio10_9"
#
# [[2]]
# [1] "CHELSA_bio10_10" "CHELSA_bio10_5"  "CHELSA_bio10_8"
#
# [[3]]
# [1] "CHELSA_bio10_12" "CHELSA_bio10_13" "CHELSA_bio10_16"
#
# [[4]]
# [1] "CHELSA_bio10_14" "CHELSA_bio10_15" "CHELSA_bio10_17"
#
# [[5]]
# [1] "CHELSA_bio10_19"
#
# [[6]]
# [1] "CHELSA_bio10_2" "CHELSA_bio10_7"
#
# [[7]]
# [1] "CHELSA_bio10_3" "CHELSA_bio10_4"

# %%
# %%R
# removeCollinearity(env,plot=TRUE)
# Out:
# [[1]]
# [1] "BDRICM_M_1km_ll"
#
# [[2]]
# [1] "BDRLOG_M_1km_ll"
#
# [[3]]
# [1] "BDTICM_M_1km_ll"
#
# [[4]]
# [1] "BLDFIE_M_sl1_1km_ll" "BLDFIE_M_sl2_1km_ll" "BLDFIE_M_sl3_1km_ll"
# [4] "BLDFIE_M_sl4_1km_ll" "BLDFIE_M_sl5_1km_ll" "BLDFIE_M_sl6_1km_ll"
# [7] "BLDFIE_M_sl7_1km_ll"

# %%
# %%R
# removeCollinearity(env,plot=TRUE)
# Out:
# [[1]]
# [1] "PHIHOX_M_sl1_1km_ll" "PHIHOX_M_sl2_1km_ll" "PHIHOX_M_sl3_1km_ll"
# [4] "PHIHOX_M_sl4_1km_ll" "PHIHOX_M_sl5_1km_ll" "PHIHOX_M_sl6_1km_ll"
# [7] "PHIHOX_M_sl7_1km_ll"
#
# [[2]]
# [1] "PHIKCL_M_sl1_1km_ll" "PHIKCL_M_sl2_1km_ll" "PHIKCL_M_sl3_1km_ll"
# [4] "PHIKCL_M_sl4_1km_ll" "PHIKCL_M_sl5_1km_ll" "PHIKCL_M_sl6_1km_ll"
# [7] "PHIKCL_M_sl7_1km_ll"

# %%
# %%R
# removeCollinearity(env,plot=TRUE)
# Out:
# [[1]]
# [1] "CECSOL_M_sl1_1km_ll" "CECSOL_M_sl2_1km_ll" "CECSOL_M_sl3_1km_ll"
# [4] "CECSOL_M_sl4_1km_ll" "CECSOL_M_sl5_1km_ll" "CECSOL_M_sl6_1km_ll"
# [7] "CECSOL_M_sl7_1km_ll"

# %%
# %%R
# removeCollinearity(env,plot=TRUE)
# Out:
# [[1]]
# [1] "CRFVOL_M_sl1_1km_ll" "CRFVOL_M_sl2_1km_ll" "CRFVOL_M_sl3_1km_ll"
# [4] "CRFVOL_M_sl4_1km_ll" "CRFVOL_M_sl5_1km_ll" "CRFVOL_M_sl6_1km_ll"
#
# [[2]]
# [1] "CRFVOL_M_sl7_1km_ll"

# %%
# %%R
# removeCollinearity(env,plot=TRUE)
# Out:
# [[1]]
# [1] "OCDENS_M_sl1_1km_ll"
#
# [[2]]
# [1] "OCDENS_M_sl2_1km_ll"  "OCDENS_M_sl3_1km_ll"  "OCDENS_M_sl4_1km_ll"
# [4] "OCSTHA_M_30cm_1km_ll" "OCSTHA_M_sd2_1km_ll"  "OCSTHA_M_sd3_1km_ll"
# [7] "ORCDRC_M_sl2_1km_ll"  "ORCDRC_M_sl3_1km_ll"
#
# [[3]]
# [1] "OCDENS_M_sl5_1km_ll" "OCDENS_M_sl6_1km_ll" "OCDENS_M_sl7_1km_ll"
#
# [[4]]
# [1] "OCSTHA_M_100cm_1km_ll" "OCSTHA_M_200cm_1km_ll" "OCSTHA_M_sd4_1km_ll"
# [4] "OCSTHA_M_sd5_1km_ll"   "OCSTHA_M_sd6_1km_ll"   "ORCDRC_M_sl4_1km_ll"
# [7] "ORCDRC_M_sl5_1km_ll"   "ORCDRC_M_sl6_1km_ll"   "ORCDRC_M_sl7_1km_ll"
#
# [[5]]
# [1] "OCSTHA_M_sd1_1km_ll" "ORCDRC_M_sl1_1km_ll"

# %%
# %%R -w 500 -h 500
# removeCollinearity(env,plot=TRUE)
# Out:
# R[write to console]:   - No multicollinearity detected in your data at threshold 0.7
#  [1] "Annual_Mean_Temperature"   "Annual_Precipitation"
#  [3] "CEC"                       "Cly"
#  [5] "Coarse_Fragments_0m"       "Coarse_Fragments_2m"
#  [7] "Isothermality"             "Organic_Carbon_Density"
#  [9] "pH"                        "Precipitation_Seasonality"
# [11] "Silt"                      "Temperature_Annual_Range"
